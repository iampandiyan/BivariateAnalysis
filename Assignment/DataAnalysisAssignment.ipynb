# %%
import pandas as pd
from Univariate import Univariate
univariateObj=Univariate()
dataset=pd.read_csv('Placement_Data_Full_Class.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    float64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 25.6+ KB

# %%
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %% [markdown]
# #1)Replace the NaN values with correct value. And justify why you have chosen the same.
# # a) Remove the empty rows
# # b) Reomove the Sl.No Column
# # c) Replace the NaN in Salary by Zero because we have NaN only for the Not placed students
# # d) We have lesser outlier for ['hsc_p']  and greater outlier for ['hsc_p', 'degree_p', 'salary']. Lesser outlier replaced by Min value and greater Outlier is replaced by Max value

# %%
#Removed 2 empty rows
dataset = dataset.dropna(how='all')

# %%
dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset[dataset['salary'].isna()]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3      4.0      M   56.0  Central   52.0  Central   Science     52.00
# 5      6.0      M   55.0   Others   49.8   Others   Science     67.25
# 6      7.0      F   46.0   Others   49.2   Others  Commerce     79.00
# 11    10.0      M   58.0  Central   70.0  Central  Commerce     61.00
# 14    13.0      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 200  199.0      F   67.0  Central   70.0  Central  Commerce     65.00
# 203  202.0      M   54.2  Central   63.0   Others   Science     58.00
# 208  207.0      M   41.0  Central   42.0  Central   Science     60.00
# 210  209.0      F   43.0  Central   60.0   Others   Science     65.00
# 216  215.0      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#Replace Nan cell with Zero
dataset.fillna({"salary": 0},inplace=True)
dataset
# Out:
# C:\Users\Pandiyan\AppData\Local\Temp\ipykernel_11180\2235154282.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.fillna({"salary": 0},inplace=True)
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
lesserOutlier,greaterOutlier=univariateObj.getOutliers(dataset)

# %%
print(lesserOutlier)
print(greaterOutlier)
# Out:
# ['hsc_p']
# ['hsc_p', 'degree_p', 'salary']

# %%
#Remove Outliers
univariateObj.removeOutlier(dataset)

# %%
lesserOutlier,greaterOutlier=univariateObj.getOutliers(dataset)

# %%
print(lesserOutlier)
print(greaterOutlier)
# Out:
# []
# []

# %% [markdown]
# # 2)How many of them are not placed?
# #  67

# %%
dataset[dataset['status']=='Not Placed'].shape[0]
# Out:
# 67

# %% [markdown]
# # 3)Find the reason for non placement from the dataset?
# #Based on Mean:
# #Students are not placed because they have the less academic scores.
# #(SSC:57.54403 vs 71.721486)
# #(HSC:58.598358 vs 69.837027)
# #(Degree:61.134179 vs 68.723649)
# #(mba:61.612836 vs 62.579392)
# #
# #Students are not placed because they have the less entrance test score.
# #(eTest:69.58791  vs 73.238041)
# #
# #Based on Percentile:
# #
# #75% of the non placed students scored below 63.0 score in ssc whereas placed students scored 78.125
# #75% of the non placed students scored below 64.0 score in hsc whereas placed students scored 75.25
# #75% of the non placed students scored below 65.0 score in degree whereas placed students scored 72.4225
# #75% of the non placed students scored below 76.5 score in entrace test whereas placed students scored 85.0
# #75% of the non placed students scored below 65.405 score in ssc whereas placed students scored 66.76

# %%
notPlacedDataset=dataset[dataset['status']=='Not Placed']
placedDataset=dataset[dataset['status']=='Placed']

# %%
notPlacedDataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3      4.0      M   56.0  Central  52.00  Central   Science     52.00
# 5      6.0      M   55.0   Others  49.80   Others   Science     67.25
# 6      7.0      F   46.0   Others  49.20   Others  Commerce     79.00
# 11    10.0      M   58.0  Central  70.00  Central  Commerce     61.00
# 14    13.0      F   47.0  Central  55.00   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 200  199.0      F   67.0  Central  70.00  Central  Commerce     65.00
# 203  202.0      M   54.2  Central  63.00   Others   Science     58.00
# 208  207.0      M   41.0  Central  42.75  Central   Science     60.00
# 210  209.0      F   43.0  Central  60.00   Others   Science     65.00
# 216  215.0      M   62.0  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
placedDataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 9      8.0      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 211  210.0      M  62.00  Central  72.00  Central  Commerce     65.00
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
univariateObj.createDescriptiveTable(notPlacedDataset)
# Out:
#                 sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean       110.477612   57.54403  58.598358  61.134179   69.58791  61.612836
# Median          107.0      56.28      60.33       61.0       67.0      60.69
# Mode              4.0       52.0      42.75       65.0       60.0      51.21
# Q1:25%           48.5       52.0       51.0       57.0       60.0      58.48
# Q2:50%          107.0      56.28      60.33       61.0       67.0      60.69
# Q3:75%          170.5       63.0       64.0       65.0       76.5     65.405
# 99%               NaN        NaN        NaN        NaN        NaN        NaN
# Q4:100%         215.0       77.8       82.0       79.0       97.0      75.71
# IQR             122.0       11.0       13.0        8.0       16.5      6.925
# 1.5rule         183.0       16.5       19.5       12.0      24.75    10.3875
# Lesser         -134.5       35.5       31.5       45.0      35.25    48.0925
# ...

# %%
univariateObj.createDescriptiveTable(placedDataset)
# Out:
#                sl_no      ssc_p      hsc_p   degree_p     etest_p      mba_p  \
# Mean      106.878378  71.721486  69.837027  68.723649   73.238041  62.579392
# Median         108.5       72.5       68.0       68.0        72.0     62.245
# Mode             1.0       73.0       63.0       65.0        60.0       56.7
# Q1:25%         57.75       65.0       63.0       65.0        60.0    57.7725
# Q2:50%         108.5       72.5       68.0       68.0        72.0     62.245
# Q3:75%        153.25     78.125      75.25    72.4225        85.0      66.76
# 99%              NaN        NaN        NaN        NaN         NaN        NaN
# Q4:100%        214.0       89.4      91.15       88.5        98.0      77.89
# IQR             95.5     13.125      12.25     7.4225        25.0     8.9875
# 1.5rule       143.25    19.6875     18.375   11.13375        37.5   13.48125
# Lesser         -85.5    45.3125     44.625   53.86625        22.5   44.29125
# ...

# %% [markdown]
# # 4)What kind of relation between salary and mba_p
# # 0.141417	Low degree positive correlation

# %%
dataset.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327  0.001217
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %% [markdown]
# # 5)Which specialization is getting minimum salary?
# # Both 'Mkt&Fin'and 'Mkt&HR' are having the minumum salary 200000.0

# %%
#dataset[dataset['salary']>0]['salary'].min()
non_zero_salary = dataset[dataset['salary'] > 0]
dataset[dataset['salary']==non_zero_salary['salary'].min()]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 17    16.0      F  65.00  Central  75.00  Central  Commerce     69.00
# 46    45.0      F  77.00   Others  73.00   Others  Commerce     81.00
# 52    51.0      F  75.20  Central  73.20  Central   Science     68.40
# 109  108.0      M  82.00   Others  90.00   Others  Commerce     83.00
# 137  136.0      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 17   Comm&Mgmt    Yes     72.0        Mkt&Fin  64.66  Placed  200000.0
# 46   Comm&Mgmt    Yes     89.0        Mkt&Fin  69.70  Placed  200000.0
# 52   Comm&Mgmt     No     65.0         Mkt&HR  62.98  Placed  200000.0
# 109  Comm&Mgmt     No     80.0         Mkt&HR  73.52  Placed  200000.0
# ...

# %% [markdown]
# #  6)How many of them getting above 500000 salary?
# # 3 students got more than 500000 salary

# %%
dataset[dataset['salary']>500000]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 121  120.0      M   60.8  Central  68.40  Central  Commerce      64.6
# 152  151.0      M   71.0  Central  58.66  Central   Science      58.0
# 179  178.0      F   73.0  Central  91.15   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 121  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  706250.0
# 152   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 179  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
dataset[dataset['salary']>500000].shape[0]
# Out:
# 3

# %% [markdown]
# # 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)
# # Pvalue is 1.9407478346570754e-24 > 0.05 Hence, There is a significance difference between the etest_p and mba_p of students

# %%
#One Way Classification
import scipy.stats as stats
f_statistic,p_value=stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
print("F-statistic:", f_statistic)
print("p-value:", p_value)
H0='There is no significance difference between the etest_p and mba_p of students'
H1='There is a significance difference between the etest_p and mba_p of students'
if p_value < 0.05:
    print(H1)
else:
    print(H0)
# Out:
# F-statistic: 98.64487057324706
# p-value: 4.672547689133573e-21
# There is a significance difference between the etest_p and mba_p of students

# %% [markdown]
# # 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_rel
etest_p=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mba_p=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
stat,pval=ttest_rel(etest_p,mba_p)
print(pval)
H0='There is no similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%'
H1='There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%'
if(pval<0.05):
    print(H1)
else:
    print(H0)
# Out:
# 5.517920600505392e-06
# There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%

# %% [markdown]
# # 9)Convert the normal distribution to standard normal distribution for salary column

# %%
univariateObj.stdNormalDistributionGraph(dataset['salary'])
# Out:
# C:\Storage\AI Development\GITCHECKOUT\BivariateAnalysis\Assignment\Univariate.py:96: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# # 10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
univariateObj.get_pdf_probability(dataset['salary'],700000,900000)
# Out:
# C:\Storage\AI Development\GITCHECKOUT\BivariateAnalysis\Assignment\Univariate.py:73: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=197615.116, Standard Deviation:150305.844
# The Area between range (700000,900000) is 0.0004137812663830059
# 0.0004137812663830059

# %% [markdown]
# # 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_rel
etest_p=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mba_p=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
stat,pval=ttest_rel(etest_p,mba_p)
print(pval)
H0='There is no similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%'
H1='There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%'
if(pval<0.05):
    print(H1)
else:
    print(H0)
# Out:
# 5.517920600505392e-06
# There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%

# %% [markdown]
# # 12)Which parameter is highly correlated with salary?

# %%
correlation_matrix=dataset.corr(numeric_only=True)
salary_correlation = correlation_matrix['salary'].sort_values(ascending=False)

print("Correlation of each parameter with salary:")
print(salary_correlation)
highest_correlation_parameter = salary_correlation.index[1]
highest_correlation_value = salary_correlation.iloc[1]

print(f"The parameter most highly correlated with salary is: {highest_correlation_parameter}")
print(f"Correlation value: {highest_correlation_value}")
# Out:
# Correlation of each parameter with salary:
# salary      1.000000
# ssc_p       0.558475
# hsc_p       0.459424
# degree_p    0.423762
# etest_p     0.186775
# mba_p       0.141417
# sl_no       0.001217
# Name: salary, dtype: float64
# The parameter most highly correlated with salary is: ssc_p
# Correlation value: 0.5584753689737205

# %% [markdown]
# # 13) plot any useful graph and explain it.

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
univariateObj.stdNormalDistributionGraph(dataset['salary'])
# Out:
# C:\Storage\AI Development\GITCHECKOUT\BivariateAnalysis\Assignment\Univariate.py:96: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
univariateObj.get_pdf_probability(dataset['salary'],700000,900000)
# Out:
# C:\Storage\AI Development\GITCHECKOUT\BivariateAnalysis\Assignment\Univariate.py:73: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=197615.116, Standard Deviation:150305.844
# The Area between range (700000,900000) is 0.0004137812663830059
# 0.0004137812663830059

# %%
import matplotlib.pyplot as plt
x=dataset['ssc_p']
y=dataset['salary']
plt.scatter(x,y,c='Blue')
plt.xlabel("SSC Mark")
plt.ylabel("Salary")
plt.title('SSC Mark Vs Salary')
plt.show()

# %%
dataset['ssc_p']
# Out:
# 0      67.00
# 1      79.33
# 2      65.00
# 3      56.00
# 4      85.80
#        ...
# 212    80.60
# 213    58.00
# 214    67.00
# 215    74.00
# 216    62.00
# Name: ssc_p, Length: 215, dtype: float64
